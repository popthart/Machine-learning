# %% [markdown]
# <a href="https://colab.research.google.com/github/popthart/Machine-learning/blob/cs-homework/DiamondsHomework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Homework 1
# # Diamonds.csv reading

# %%
import pandas as pd

# %%
diamonds = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv', index_col=0)

# %%
pd.set_option('display.precision', 2)

# %%
diamonds.columns = diamonds.columns.str.replace('_', ' ').str.title()

# %% [markdown]
# # Display first and last seven columns

# %%
diamonds.head(7)
# Out:
#           Carat        Cut Color Clarity  Depth  Table  Price     X     Y  \
# rownames
# 1          0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2          0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4          0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5          0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 6          0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 7          0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
#
#              Z
# rownames
# 1         2.43
# 2         2.31
# 3         2.31
# 4         2.63
# 5         2.75
# 6         2.48
# 7         2.47

# %%
diamonds.tail(7)
# Out:
#           Carat        Cut Color Clarity  Depth  Table  Price     X     Y  \
# rownames
# 53934      0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
# 53935      0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73
# 53936      0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53937      0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53938      0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53939      0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53940      0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#              Z
# rownames
# 53934     3.49
# 53935     3.58
# 53936     3.50
# 53937     3.61
# 53938     3.56
# 53939     3.74
# 53940     3.64

# %% [markdown]
# # Describing numerical and text data

# %%
diamonds.describe()
# Out:
#           Carat     Depth     Table     Price         X         Y         Z
# count  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00
# mean       0.80     61.75     57.46   3932.80      5.73      5.73      3.54
# std        0.47      1.43      2.23   3989.44      1.12      1.14      0.71
# min        0.20     43.00     43.00    326.00      0.00      0.00      0.00
# 25%        0.40     61.00     56.00    950.00      4.71      4.72      2.91
# 50%        0.70     61.80     57.00   2401.00      5.70      5.71      3.53
# 75%        1.04     62.50     59.00   5324.25      6.54      6.54      4.04
# max        5.01     79.00     95.00  18823.00     10.74     58.90     31.80

# %%
diamonds[['Cut', 'Color', 'Clarity']].describe(include='object')
# Out:
#           Cut  Color Clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# # Displaying unique values

# %%
diamonds['Cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds['Color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamonds['Clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %% [markdown]
# # Displaying histographs on data, manipulating the format to fit

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
diamonds.hist()
plt.tight_layout()
plt.show()
