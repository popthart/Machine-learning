# %% [markdown]
# <a href="https://colab.research.google.com/github/popthart/Machine-learning/blob/cs-homework/Week3HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
k_range = range(1, 31)

# %%
cv_scores = []

# %%
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors=k)
  scores = cross_val_score(knn, X, y, cv=10)
  cv_scores.append(np.mean(scores))

# %%
optimal_k = k_range[np.argmax(cv_scores)]
best_score = max(cv_scores)

# %%
print(f'Optimal k: {optimal_k}')
print(f'Best cross validated accuracy: {best_score: .4f}')
# Out:
# Optimal k: 13
# Best cross validated accuracy:  0.9800

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.plot(k_range, cv_scores, marker='o')
plt.title('Plot 1')
plt.xlabel('Value of K in KNN')
plt.ylabel('Cross Validated Accuracy')
plt.xticks(np.arange(0, 31, 5))
plt.grid(True)

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 2)
plt.plot(k_range, cv_scores, marker='o')
plt.title('Plot 2')
plt.xlabel('Value of K in KNN')
plt.ylabel('Cross Validated Accuracy')
plt.xlim(11, 15)
plt.xticks(np.arange(11, 16, .5))
plt.grid(True)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_neighbors': range(1, 31)}

# %%
knn = KNeighborsClassifier()

# %%
grid_search = GridSearchCV(knn, param_grid, cv=10)

# %%
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 31)})

# %%
print("Best parameters:", grid_search.best_params_)
print("Best cros val score:", grid_search.best_score_)
# Out:
# Best parameters: {'n_neighbors': 13}
# Best cros val score: 0.9800000000000001
